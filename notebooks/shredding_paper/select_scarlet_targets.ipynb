# %% [markdown]
# ### In this section, we explore the sample on which we will run the scarlet model!!
#
# Some things I want to do with the eventual final scarlet test:
#
# 1) build scarlet models for nearby low-mass dwarf galaxies. Nearby as most likely to be shredded, and low mass so angular size is smaller and thus less expensive
#
# 2) Want to make a plot comparing the scarlet mags with aperture photo mags
#
# 3) When do we need the LSB wavelet component included or not?
#
# 4) Need to visually inspect ones to avoid repetition
#
# 3) For the most irregular ones, make a scarlet model highlighting how future directions could be useful here??
#
# In constructing the scarlet model, need to thing about how to thing about masking other sources outside main island .. and how large to choose the cutout size

# %%
import os
import sys

import numpy as np
from tqdm import trange
from astropy.io import fits
from astropy.table import Table, vstack
from astropy.convolution import convolve, Gaussian1DKernel
import astropy.units as u
import astropy.coordinates as coord
import matplotlib
import matplotlib.pyplot as plt
from astropy.table import Column
from tqdm import trange
import pandas as pd
import fitsio
from astropy.table import Table, vstack
from astropy import units as u
from astropy.coordinates import SkyCoord
from easyquery import Query, QueryMaker
from scipy.stats import binomtest
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import LogNorm
from matplotlib.colors import ListedColormap, BoundaryNorm
import h5py
from astropy.cosmology import Planck18

mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['axes.linewidth'] = 1.5
mpl.rcParams['axes.xmargin'] = 1
mpl.rcParams['xtick.labelsize'] = 'x-large'
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['xtick.major.width'] = 1.5
mpl.rcParams['ytick.labelsize'] = 'x-large'
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['ytick.major.width'] = 1.5
mpl.rcParams['legend.frameon'] = False

rootdir = '/global/u1/v/virajvm/'
sys.path.append(os.path.join(rootdir, 'DESI2_LOWZ/desi_dwarfs/code'))

from desi_lowz_funcs import make_subplots, print_radecs, sdss_rgb

# %%
import numpy as np
from astropy.coordinates import SkyCoord
import astropy.units as u

from desi_lowz_funcs import get_stellar_mass_mia

def filter_close_sources(ra, dec, radius_arcsec=30):
    """
    Remove sources that lie within <radius_arcsec of another source.
    Keeps the first instance encountered.

    ra, dec : arrays in degrees
    returns : indices of the sources to keep
    """
    coords = SkyCoord(ra=ra*u.degree, dec=dec*u.degree, frame='icrs')
    keep = []
    mask = np.ones(len(coords), dtype=bool)

    for i in range(len(coords)):
        if not mask[i]:
            continue  # this one was already excluded
        keep.append(i)
        # mark all others within the radius as excluded
        sep = coords[i].separation(coords)
        mask[sep < (radius_arcsec*u.arcsec)] = False

    return np.array(keep)



def basic_filter_scarlet(data):
    data_scarlet = data[(data["Z"] < 0.01) & (data["LOG_MSTAR_M24"] < 8.5) & (data["LOG_MSTAR_M24"] > 6) 
                        & (data["MASKBITS"]==0) & (data["is_south"] == 1)  ]

    return data_scarlet
    

def do_consolidate(cat,sample):
    '''
    Here we consolidate the photo
    '''
    
    cat = consolidate_new_photo(cat,sample=sample, use_pcnn=False)

    cat = cat[cat["PHOTO_MASKBIT"] == 0]

    ra_tgt = cat["RA"].data
    dec_tgt = cat["DEC"].data
    
    cat = consolidate_positions_and_shapes(cat)

    cat["RA_TARGET"] = ra_tgt
    cat["DEC_TARGET"] = dec_tgt

    #add stellar mass
    gr_colors = cat["MAG_G_BEST"].data - cat["MAG_R_BEST"].data
    log_mstars_M24 = get_stellar_mass_mia(gr_colors, cat["MAG_G_BEST"].data , cat["Z_CMB"].data, d_in_mpc = cat["DIST_MPC_FIDU"].data, input_zred =  False)

    cat["LOG_MSTAR_M24"] = log_mstars_M24
    
    return cat
    

def get_entire_scarlet():

    data_bgsb = Table.read("/pscratch/sd/v/virajvm/catalog_dr1_dwarfs/iron_photometry/iron_BGS_BRIGHT_shreds_catalog_w_aper_mags.fits")
    data_bgsf = Table.read("/pscratch/sd/v/virajvm/catalog_dr1_dwarfs/iron_photometry/iron_BGS_FAINT_shreds_catalog_w_aper_mags.fits")
    data_lowz = Table.read("/pscratch/sd/v/virajvm/catalog_dr1_dwarfs/iron_photometry/iron_LOWZ_shreds_catalog_w_aper_mags.fits")
    data_elg = Table.read("/pscratch/sd/v/virajvm/catalog_dr1_dwarfs/iron_photometry/iron_ELG_shreds_catalog_w_aper_mags.fits")


    ##consolidate photo into best and measure stellar mass
    data_bgsb = do_consolidate(data_bgsb, "BGS_BRIGHT")
    data_bgsf = do_consolidate(data_bgsf, "BGS_FAINT")
    data_lowz = do_consolidate(data_lowz, "LOWZ")
    data_elg = do_consolidate(data_elg, "ELG")

    data_bgsb = basic_filter_scarlet(data_bgsb)
    data_bgsf = basic_filter_scarlet(data_bgsf)
    data_lowz = basic_filter_scarlet(data_lowz)
    data_elg = basic_filter_scarlet(data_elg)

    print(len(data_bgsb), len(data_bgsf), len(data_lowz), len(data_elg))

    data_all = vstack([data_bgsb, data_bgsf, data_lowz, data_elg])

    print(len(data_all))
    
    # example usage:
    keep_indices = filter_close_sources( data_all["RA"].data, data_all["DEC"].data, radius_arcsec = 60 )

    data_all = data_all[keep_indices]

    print(len(data_all))

    return data_all

# %%
from consolidate_photometry import consolidate_new_photo, consolidate_positions_and_shapes

# %%
data_scarlet_f = get_entire_scarlet()
# Out:
# Added PCNN values!
# FRACTION REVERT BACK TO TRACTOR: 0.23541726139499478
# Need to include the VI column that only does the aperture no subtract photo
# Adding the photo maskbits
# MASKBIT=2^0, cog nan mask, 0.0030
# MASKBIT=2^1, cog not converge, fraction: 0.059616
# MASKBIT=2^2, bad resid, fraction : 0.0056
# MASKBIT=2^3, cog curve decrease, fraction: 0.0095
# MASKBIT=2^4, aperfrac-in image, fraction: 0.000999
# MASKBIT=2^5, aperfrac-mask image, fraction: 0.047055
# MASKBIT=2^6, image-frac mask, fraction: 0.000809
# MASKBIT=2^7, bad colors, fraction: 0.000333
# MASKBIT=2^8, source not on segment, fraction: 0.0000
# MASKBIT=2^9, within star mask radius and not just a simple blend, fraction: 0.102151
# MASKBIT=2^10, aper-cen masked, fraction: 0.048958
# MASKBIT=2^11, no seg found, fraction: 0.000048
# MASKBIT=2^12, near sga outskirts, fraction: 0.013798
# Fraction of sources where org trac is likely good = 0.5378247216671425
# Updating the maskbits to reflect some objects reverted to original Tractor photometry
# MASKBIT=2^0, cog nan mask, 0.0030
# MASKBIT=2^7, bad colors, fraction: 0.000333
# MASKBIT=2^11, no seg found, fraction: 0.000048
# MASKBIT=2^12, near sga outskirts, fraction: 0.013798
# MASKBIT=2^13, bad rchisq, fraction: 0.131221
# MASKBIT=2^14, low snr, fraction: 0.001903
# MASKBIT=2^15, Tractor maskbit flagged: 0.0403
#
# --- Maskbit Statistics (n = 21018) ---
# Fraction with no maskbit on = 0.8701113331430202
# Bit  0 (2^0  =    1)  ->  0.30% fraction
# Bit  1 (2^1  =    2)  ->  1.15% fraction
# Bit  2 (2^2  =    4)  ->  0.22% fraction
# Bit  3 (2^3  =    8)  ->  0.53% fraction
# Bit  4 (2^4  =   16)  ->  0.08% fraction
# Bit  5 (2^5  =   32)  ->  0.43% fraction
# Bit  6 (2^6  =   64)  ->  0.03% fraction
# Bit  7 (2^7  =  128)  ->  0.03% fraction
# Bit  8 (2^8  =  256)  ->  0.00% fraction
# Bit  9 (2^9  =  512)  ->  2.44% fraction
# Bit 10 (2^10 = 1024)  ->  0.75% fraction
# Bit 11 (2^11 = 2048)  ->  0.00% fraction
# Bit 12 (2^12 = 4096)  ->  1.38% fraction
# Bit 13 (2^13 = 8192)  ->  5.52% fraction
# Adding the consolidated RA,DEC, and SHAPE columns
# 100%|██████████| 18288/18288 [00:00<00:00, 282595.39it/s]
# 100%|██████████| 18288/18288 [00:00<00:00, 286586.43it/s]
# Consolidated RA, DEC, and SHAPE_PARAMS columns added. Added PHOTOMETRY_UPDATED column
# Added PCNN values!
# FRACTION REVERT BACK TO TRACTOR: 0.31032412965186074
# Need to include the VI column that only does the aperture no subtract photo
# Adding the photo maskbits
# MASKBIT=2^0, cog nan mask, 0.0096
# MASKBIT=2^1, cog not converge, fraction: 0.082233
# MASKBIT=2^2, bad resid, fraction : 0.0114
# MASKBIT=2^3, cog curve decrease, fraction: 0.0066
# MASKBIT=2^4, aperfrac-in image, fraction: 0.000300
# MASKBIT=2^5, aperfrac-mask image, fraction: 0.124850
# MASKBIT=2^6, image-frac mask, fraction: 0.000900
# MASKBIT=2^7, bad colors, fraction: 0.000600
# MASKBIT=2^8, source not on segment, fraction: 0.0000
# MASKBIT=2^9, within star mask radius and not just a simple blend, fraction: 0.110444
# MASKBIT=2^10, aper-cen masked, fraction: 0.110144
# MASKBIT=2^11, no seg found, fraction: 0.000300
# MASKBIT=2^12, near sga outskirts, fraction: 0.006603
# Fraction of sources where org trac is likely good = 0.46278511404561823
# Updating the maskbits to reflect some objects reverted to original Tractor photometry
# MASKBIT=2^0, cog nan mask, 0.0096
# MASKBIT=2^7, bad colors, fraction: 0.000600
# MASKBIT=2^11, no seg found, fraction: 0.000300
# MASKBIT=2^12, near sga outskirts, fraction: 0.006603
# MASKBIT=2^13, bad rchisq, fraction: 0.102341
# MASKBIT=2^14, low snr, fraction: 0.000300
# MASKBIT=2^15, Tractor maskbit flagged: 0.0384
#
# --- Maskbit Statistics (n = 3332) ---
# Fraction with no maskbit on = 0.9051620648259304
# Bit  0 (2^0  =    1)  ->  0.96% fraction
# Bit  1 (2^1  =    2)  ->  0.57% fraction
# Bit  2 (2^2  =    4)  ->  0.33% fraction
# Bit  3 (2^3  =    8)  ->  0.30% fraction
# Bit  4 (2^4  =   16)  ->  0.00% fraction
# Bit  5 (2^5  =   32)  ->  0.48% fraction
# Bit  6 (2^6  =   64)  ->  0.06% fraction
# Bit  7 (2^7  =  128)  ->  0.06% fraction
# Bit  8 (2^8  =  256)  ->  0.00% fraction
# Bit  9 (2^9  =  512)  ->  1.23% fraction
# Bit 10 (2^10 = 1024)  ->  0.66% fraction
# Bit 11 (2^11 = 2048)  ->  0.03% fraction
# Bit 12 (2^12 = 4096)  ->  0.66% fraction
# Bit 13 (2^13 = 8192)  ->  4.05% fraction
# Adding the consolidated RA,DEC, and SHAPE columns
# 100%|██████████| 3016/3016 [00:00<00:00, 279682.09it/s]
# 100%|██████████| 3016/3016 [00:00<00:00, 276563.64it/s]
# Consolidated RA, DEC, and SHAPE_PARAMS columns added. Added PHOTOMETRY_UPDATED column
# Added PCNN values!
# FRACTION REVERT BACK TO TRACTOR: 0.5029171528588098
# Need to include the VI column that only does the aperture no subtract photo
# Adding the photo maskbits
# MASKBIT=2^0, cog nan mask, 0.0070
# MASKBIT=2^1, cog not converge, fraction: 0.185531
# MASKBIT=2^2, bad resid, fraction : 0.0023
# MASKBIT=2^3, cog curve decrease, fraction: 0.0093
# MASKBIT=2^4, aperfrac-in image, fraction: 0.000000
# MASKBIT=2^5, aperfrac-mask image, fraction: 0.024504
# MASKBIT=2^6, image-frac mask, fraction: 0.000000
# MASKBIT=2^7, bad colors, fraction: 0.000000
# MASKBIT=2^8, source not on segment, fraction: 0.0000
# MASKBIT=2^9, within star mask radius and not just a simple blend, fraction: 0.099183
# MASKBIT=2^10, aper-cen masked, fraction: 0.019837
# MASKBIT=2^11, no seg found, fraction: 0.000000
# MASKBIT=2^12, near sga outskirts, fraction: 0.002334
# Fraction of sources where org trac is likely good = 0.5052508751458576
# Updating the maskbits to reflect some objects reverted to original Tractor photometry
# MASKBIT=2^0, cog nan mask, 0.0070
# MASKBIT=2^7, bad colors, fraction: 0.000000
# MASKBIT=2^11, no seg found, fraction: 0.000000
# MASKBIT=2^12, near sga outskirts, fraction: 0.002334
# MASKBIT=2^13, bad rchisq, fraction: 0.014002
# MASKBIT=2^14, low snr, fraction: 0.000000
# MASKBIT=2^15, Tractor maskbit flagged: 0.0175
#
# --- Maskbit Statistics (n = 857) ---
# Fraction with no maskbit on = 0.9101516919486581
# Bit  0 (2^0  =    1)  ->  0.70% fraction
# Bit  1 (2^1  =    2)  ->  3.38% fraction
# Bit  2 (2^2  =    4)  ->  0.12% fraction
# Bit  3 (2^3  =    8)  ->  0.23% fraction
# Bit  4 (2^4  =   16)  ->  0.00% fraction
# Bit  5 (2^5  =   32)  ->  0.82% fraction
# Bit  6 (2^6  =   64)  ->  0.00% fraction
# Bit  7 (2^7  =  128)  ->  0.00% fraction
# Bit  8 (2^8  =  256)  ->  0.00% fraction
# Bit  9 (2^9  =  512)  ->  1.40% fraction
# Bit 10 (2^10 = 1024)  ->  1.40% fraction
# Bit 11 (2^11 = 2048)  ->  0.00% fraction
# Bit 12 (2^12 = 4096)  ->  0.23% fraction
# Bit 13 (2^13 = 8192)  ->  1.17% fraction
# Adding the consolidated RA,DEC, and SHAPE columns
# 100%|██████████| 780/780 [00:00<00:00, 279859.46it/s]
# 100%|██████████| 780/780 [00:00<00:00, 277415.17it/s]
# Consolidated RA, DEC, and SHAPE_PARAMS columns added. Added PHOTOMETRY_UPDATED column
# Added PCNN values!
# FRACTION REVERT BACK TO TRACTOR: 0.19545918768167178
# Need to include the VI column that only does the aperture no subtract photo
# Adding the photo maskbits
# MASKBIT=2^0, cog nan mask, 0.1824
# MASKBIT=2^1, cog not converge, fraction: 0.033801
# MASKBIT=2^2, bad resid, fraction : 0.0025
# MASKBIT=2^3, cog curve decrease, fraction: 0.0014
# MASKBIT=2^4, aperfrac-in image, fraction: 0.000314
# MASKBIT=2^5, aperfrac-mask image, fraction: 0.195224
# MASKBIT=2^6, image-frac mask, fraction: 0.001355
# MASKBIT=2^7, bad colors, fraction: 0.001375
# MASKBIT=2^8, source not on segment, fraction: 0.0041
# MASKBIT=2^9, within star mask radius and not just a simple blend, fraction: 0.045997
# MASKBIT=2^10, aper-cen masked, fraction: 0.017224
# MASKBIT=2^11, no seg found, fraction: 0.029991
# MASKBIT=2^12, near sga outskirts, fraction: 0.005617
# Fraction of sources where org trac is likely good = 0.19940686621101422
# Updating the maskbits to reflect some objects reverted to original Tractor photometry
# MASKBIT=2^0, cog nan mask, 0.1824
# MASKBIT=2^7, bad colors, fraction: 0.001375
# MASKBIT=2^11, no seg found, fraction: 0.029991
# MASKBIT=2^12, near sga outskirts, fraction: 0.005617
# MASKBIT=2^13, bad rchisq, fraction: 0.012472
# MASKBIT=2^14, low snr, fraction: 0.131982
# MASKBIT=2^15, Tractor maskbit flagged: 0.0209
#
# --- Maskbit Statistics (n = 50916) ---
# Fraction with no maskbit on = 0.7724683792913819
# Bit  0 (2^0  =    1)  ->  18.24% fraction
# Bit  1 (2^1  =    2)  ->  2.45% fraction
# Bit  2 (2^2  =    4)  ->  0.15% fraction
# Bit  3 (2^3  =    8)  ->  0.12% fraction
# Bit  4 (2^4  =   16)  ->  0.03% fraction
# Bit  5 (2^5  =   32)  ->  0.85% fraction
# Bit  6 (2^6  =   64)  ->  0.09% fraction
# Bit  7 (2^7  =  128)  ->  0.14% fraction
# Bit  8 (2^8  =  256)  ->  0.00% fraction
# Bit  9 (2^9  =  512)  ->  1.02% fraction
# Bit 10 (2^10 = 1024)  ->  1.07% fraction
# Bit 11 (2^11 = 2048)  ->  3.00% fraction
# Bit 12 (2^12 = 4096)  ->  0.56% fraction
# Bit 13 (2^13 = 8192)  ->  0.37% fraction
# Adding the consolidated RA,DEC, and SHAPE columns
# 100%|██████████| 39331/39331 [00:00<00:00, 283565.42it/s]
# 100%|██████████| 39331/39331 [00:00<00:00, 277072.92it/s]
# Consolidated RA, DEC, and SHAPE_PARAMS columns added. Added PHOTOMETRY_UPDATED column
# 249 5 0 40
# 294
# 250

# %% [markdown]
# ## Make some basic VI plots to check robustness of Scarlet model.
#
# ## Make plot of difference between scarlet mag and best mag

# %%
from matplotlib.patheffects import withStroke
import requests
import os
import sys
import numpy as np
from astropy.io import fits
from astropy.table import Table, vstack
import matplotlib
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import LogNorm
import matplotlib.patches as patches
from matplotlib.patches import Circle


session = requests.Session()

def get_tractor_model(ra,dec,size=350,path=None):
    '''
    We extract the model image from Tractor using hte url method
    '''
    if os.path.exists(path):
        pass
    else:
        url_prefix = 'https://www.legacysurvey.org/viewer/'
    
        url = url_prefix + f'cutout.fits?ra={ra}&dec={dec}&size=%s&'%size
        
        url += 'layer=ls-dr9-model&pixscale=0.262&bands=grz'
        resp = session.get(url)
        with open(path, "wb") as f:
            f.write(resp.content)
            
    return      

def get_tractor_model_resid(ra,dec,size=350,path=None):
    '''
    We extract the model image from Tractor using hte url method
    '''

    if os.path.exists(path):
        pass
    else:
        url_prefix = 'https://www.legacysurvey.org/viewer/'
    
        url = url_prefix + f'cutout.fits?ra={ra}&dec={dec}&size=%s&'%size
        
        url += 'layer=ls-dr9-resid&pixscale=0.262&bands=grz'
        resp = session.get(url)
        with open(path, "wb") as f:
            f.write(resp.content)
            
    return

# %%
def plot_VI(index, data_scarlet):

    ra = data_scarlet["RA"][index]
    dec = data_scarlet["DEC"][index]
    
    file_path = data_scarlet["FILE_PATH"][index]
    img_path = data_scarlet["IMAGE_PATH"][index]
    try:
        img_data_total = fits.open(img_path)[0].data
    
        tgid = data_scarlet["TARGETID"][index]
        
        # print(file_path)
        
        scar_mags = np.load( file_path + "/scarlet_mags.npy")
    
        #get the dwarf only model with scarlet
        scarlet_total_model = np.load(file_path + "/total_model_rgb.npy")
        scarlet_model_rgb = np.load(file_path + "/dwarf_model_rgb.npy")
        scarlet_resid_rgb = np.load(file_path + "/model_residual_rgb.npy")
        bounding_box_coords = np.load(file_path + "/bounding_box_coords.npy")
        
        ##### PREPARING THE ACTUAL IMAGES!
        img_data = img_data_total[:, bounding_box_coords[0] : bounding_box_coords[1], bounding_box_coords[2] : bounding_box_coords[3] ]
        img_rgb = sdss_rgb([img_data[0],img_data[1],img_data[2]], ["g","r","z"], scales=dict(g=(2,6.0), r=(1,3.4), z=(0,2.2)), m=0.03)
    
        ## load the dwarf only model with tractor!!
        
        tractor_bkg_model = np.load(file_path + "/tractor_background_model.npy")
        tractor_blend_model = np.load(file_path + "/tractor_blend_remove_model.npy")
        
        tractor_dwarf_model = img_data_total - tractor_bkg_model - tractor_blend_model
        tractor_dwarf_model = tractor_dwarf_model[ :, bounding_box_coords[0] : bounding_box_coords[1], bounding_box_coords[2] : bounding_box_coords[3] ]
        #apply the aperture mask
        aper_cog_mask = np.load(file_path + "/final_mask_cog.npy")
        aper_cog_mask = aper_cog_mask[bounding_box_coords[0] : bounding_box_coords[1], bounding_box_coords[2] : bounding_box_coords[3] ]
        
        tractor_dwarf_model[:, aper_cog_mask] = 0
        tractor_dwarf_model_rgb = sdss_rgb([tractor_dwarf_model[0],tractor_dwarf_model[1],tractor_dwarf_model[2]], ["g","r","z"], scales=dict(g=(2,6.0), r=(1,3.4), z=(0,2.2)), m=0.03)
    
        desi_fiber_pos = np.load(file_path + "/fiber_pix_pos_org.npy")
        #we need to update this 
    
        desi_fiber_pos = desi_fiber_pos - np.array([bounding_box_coords[0] , bounding_box_coords[2]] )
        
        fig,ax = make_subplots(ncol = 1, nrow = 4, return_fig = True,row_spacing = 0.)
    
        ax[3].set_title(f"{index}, {tgid}",fontsize = 15)
        ax[3].imshow(img_rgb,origin="lower",zorder = 0)
    
        radius_in_pixels = (1.5/2)/0.262 #radius of DESI fiber diameter
        circle = patches.Circle( (desi_fiber_pos[1], desi_fiber_pos[0]),radius_in_pixels, color='limegreen', fill=False, linewidth=1.5,ls ="--")
        ax[3].add_patch(circle)
        
        fs = 15
        
        ax[0].set_ylabel(r"Scarlet Residuals",fontsize = fs)
        ax[1].set_ylabel(r"Scarlet Reconstruction",fontsize = fs)
        ax[2].set_ylabel(r"Original Reconstruction",fontsize = fs)
        ax[3].set_ylabel(r"$grz$ image",fontsize = fs)
            
        ax[3].text(0.5, 0.95,f"({ra:.3f}, {dec:.3f})",color = "white",fontsize = 15,
                     transform=ax[3].transAxes, ha = "center", verticalalignment='top')
        
    
        fst = 15
        ax[2].text(
        0.5, 0.925,
        rf"$\mathrm{{mag_{{aper}}}}$: ({data_scarlet['MAG_G_BEST'][index]:.1f}, "
        rf"{data_scarlet['MAG_R_BEST'][index]:.1f}, "
        rf"{data_scarlet['MAG_Z_BEST'][index]:.1f})",
        ha="center", va="center",
        fontsize=fst, color="white",
        transform=ax[2].transAxes)
    
        ax[1].text(
        0.5, 0.925,
        rf"$\mathrm{{mag_{{scarlet}}}}$: ({scar_mags[0]:.1f}, "
        rf"{scar_mags[1]:.1f}, "
        rf"{scar_mags[2]:.1f})",
        ha="center", va="center",
        fontsize=fst, color="white",
        transform=ax[1].transAxes
    )
    
        ax[2].imshow(tractor_dwarf_model_rgb,origin="lower")    
        ax[1].imshow(scarlet_model_rgb,origin="lower")
        ax[0].imshow(scarlet_resid_rgb,origin="lower")
    
    
        org_size = np.shape(img_data)[1]
    
        for axi in ax:
            axi.set_xticks([])
            axi.set_yticks([])
    
    
            bar_frac = 15/(org_size * 0.262)
    
            x_start_frac = 0.07  # 7% from left
            y_start_frac = 0.07  # 7% from bottom
            
            # Draw the scale bar in axes coordinates
            axi.plot([x_start_frac, x_start_frac + bar_frac],
                    [y_start_frac, y_start_frac],
                    color='white', lw=1, transform=axi.transAxes)    
        

        save_path = f"/pscratch/sd/v/virajvm/trash/scarlet_comp_plots/scarlet_tractor_compare_{index}.png"
        plt.savefig(save_path,bbox_inches="tight",dpi=150)
        plt.close()

        return save_path

    except:
        plt.close()
        print(f"Error in {index}: {file_path}")

        return None

# %%
np.where(data_scarlet_f["TARGETID"]==39627409678405366)
# Out:
# (array([1]),)

# %%
all_scar_imgs = []
for index in range(len(data_scarlet_f)):
    path_i = plot_VI(index, data_scarlet_f)
    if path_i is not None:
        all_scar_imgs.append(path_i)
# Out:
# Error in 0: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-050m020-060m015/0552m187/BGS_BRIGHT_tgid_39627340371723696
# Error in 3: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-310m010-320m005/3193m100/BGS_BRIGHT_tgid_39627549499723844
# Error in 8: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-210m010-220m005/2151m077/BGS_BRIGHT_tgid_39627601534256349
# Error in 10: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-150m010-160m005/1552m070/BGS_BRIGHT_tgid_39627618525385721
# Error in 12: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-170m010-180m005/1753m065/BGS_BRIGHT_tgid_39627630869219269
# Error in 19: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-200m010-210m005/2092m055/BGS_BRIGHT_tgid_39627655481396172
# Error in 20: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-210m010-220m005/2122m052/BGS_BRIGHT_tgid_39627661550556653
# Error in 22: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-180m010-190m005/1899m050/BGS_BRIGHT_tgid_39627667200278646
# Error in 28: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-070m005-080p000/0718m045/BGS_BRIGHT_tgid_39627677270804731
# Error in 33: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-180m005-190p000/1893m042/BGS_BRIGHT_tgid_39627685265147908
# Error in 35: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-190m005-200p000/1966m042/BGS_BRIGHT_tgid_39627685386784418
# Error in 36: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-220m005-230p000/2221m042/BGS_BRIGHT_tgid_39627685814601901
# Error in 37: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-130m005-140p000/1340m040/BGS_BRIGHT_tgid_39627690369615373
# Error in 39: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-170m005-180p000/1786m040/BGS_BRIGHT_tgid_39627691116201680
# Error in 43: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-210m005-220p000/2136m037/BGS_BRIGHT_tgid_39627697734816827
# Error in 44: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-170m005-180p000/1783m035/BGS_BRIGHT_tgid_39627703174825445
# Error in 47: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-220m005-230p000/2231m035/BGS_BRIGHT_tgid_39627703925606400
# Error in 49: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-210m005-220p000/2129m032/BGS_BRIGHT_tgid_39627709785048356
# Error in 51: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-180m005-190p000/1893m030/BGS_BRIGHT_tgid_39627715426386300
# Error in 52: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-170m005-180p000/1701m027/BGS_BRIGHT_tgid_39627721143225249
# Error in 53: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-040m005-050p000/0448m022/BGS_BRIGHT_tgid_39627731121475031
# Error in 55: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-050m005-060p000/0571m020/BGS_BRIGHT_tgid_39627737366791864
# Error in 59: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-170m005-180p000/1746m017/BGS_BRIGHT_tgid_39627745377915523
# Error in 61: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-200m005-210p000/2076m017/BGS_BRIGHT_tgid_39627745931561354
# Error in 63: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-180m005-190p000/1853m015/BGS_BRIGHT_tgid_39627751598068708
# Error in 68: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-180m005-190p000/1873m012/BGS_BRIGHT_tgid_39627757671416924
# Error in 70: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-220m005-230p000/2273m010/BGS_BRIGHT_tgid_39627764382305600
# Error in 71: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-170m005-180p000/1781m007/BGS_BRIGHT_tgid_39627769595826961
# Error in 72: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-180m005-190p000/1831m005/BGS_BRIGHT_tgid_39627775719507449
# Error in 74: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-220m005-230p000/2206m005/BGS_BRIGHT_tgid_39627776348656318
# Error in 77: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-340m005-350p000/3408m005/BGS_BRIGHT_tgid_39627778366119602
# Error in 78: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-160m005-170p000/1606m002/BGS_BRIGHT_tgid_39627781381822361
# Error in 80: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-140m005-150p000/1473p000/BGS_BRIGHT_tgid_39627787199317730
# Error in 83: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-220p000-230p005/2261p005/BGS_BRIGHT_tgid_39627800600122885
# Error in 84: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-140p000-150p005/1453p007/BGS_BRIGHT_tgid_39627805285156137
# Error in 87: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-190p000-200p005/1931p007/BGS_BRIGHT_tgid_39627806086268813
# Error in 88: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-230p000-240p005/2353p007/BGS_BRIGHT_tgid_39627806795105012
# Error in 95: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-140p000-150p005/1496p017/BGS_BRIGHT_tgid_39627829515651432
# Error in 100: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-220p000-230p005/2263p020/BGS_BRIGHT_tgid_39627836843098565
# Error in 107: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-120p000-130p005/1261p027/BGS_BRIGHT_tgid_39627853280579157
# Error in 108: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-190p000-200p005/1911p027/BGS_BRIGHT_tgid_39627854371096150
# Error in 109: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-210p000-220p005/2188p027/BGS_BRIGHT_tgid_39627854836665742
# Error in 117: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-020p000-030p005/0239p035/BGS_BRIGHT_tgid_39627869676112539
# Error in 118: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-040p000-050p005/0446p035/BGS_BRIGHT_tgid_39627870024241455
# Error in 124: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-010p000-020p005/0191p040/BGS_BRIGHT_tgid_39627881659238563
# Error in 134: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-150p005-160p010/1535p052/BGS_BRIGHT_tgid_39627914039266696
# Error in 136: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-210p005-220p010/2199p052/BGS_BRIGHT_tgid_39627915150755591
# Error in 137: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-220p005-230p010/2200p055/BGS_BRIGHT_tgid_39627921169584741
# Error in 141: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-230p005-240p010/2393p060/BGS_BRIGHT_tgid_39627933521808441
# Error in 146: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-250p005-260p010/2545p065/BGS_BRIGHT_tgid_39627945790150534
# Error in 151: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-160p005-170p010/1695p077/BGS_BRIGHT_tgid_39627974370132829
# Error in 152: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-200p005-210p010/2043p077/BGS_BRIGHT_tgid_39627974948948833
# Error in 153: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-190p005-200p010/1957p080/BGS_BRIGHT_tgid_39627980795807972
# Error in 156: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-020p005-030p010/0210p082/BGS_BRIGHT_tgid_39627983878620550
# Error in 159: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-350p005-360p010/3502p085/BGS_BRIGHT_tgid_39627995329070768
# Error in 160: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-030p005-040p010/0342p087/BGS_BRIGHT_tgid_39627996058879884
# Error in 163: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-020p010-030p015/0214p110/BGS_BRIGHT_tgid_39628049464952793
# Error in 164: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-120p010-130p015/1219p110/BGS_BRIGHT_tgid_39628051121704180
# Error in 165: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-350p010-360p015/3508p130/BGS_BRIGHT_tgid_39628102187353070
# Error in 166: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-220p010-230p015/2232p132/BGS_BRIGHT_tgid_39628105987394067
# Error in 168: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-020p010-030p015/0235p137/BGS_BRIGHT_tgid_39628114489247325
# Error in 172: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-340p010-350p015/3490p142/BGS_BRIGHT_tgid_39628131526510434
# Error in 173: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-020p010-030p015/0248p145/BGS_BRIGHT_tgid_39628132109520797
# Error in 174: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-020p010-030p015/0244p147/BGS_BRIGHT_tgid_39628137956378343
# Error in 176: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-260p015-270p020/2627p155/BGS_BRIGHT_tgid_39628159338939751
# Error in 178: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-120p015-130p020/1239p170/BGS_BRIGHT_tgid_39628191928684316
# Error in 179: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-340p015-350p020/3465p170/BGS_BRIGHT_tgid_39628195502229087
# Error in 182: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-160p015-170p020/1670p175/BGS_BRIGHT_tgid_39628204176051187
# Error in 184: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-230p015-240p020/2366p182/BGS_BRIGHT_tgid_39628222563877276
# Error in 185: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-240p015-250p020/2453p185/BGS_BRIGHT_tgid_39628228444292174
# Error in 187: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-170p020-180p025/1740p202/BGS_BRIGHT_tgid_39628267266770786
# Error in 188: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-350p020-360p025/3566p207/BGS_BRIGHT_tgid_39628281464490658
# Error in 189: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-250p020-260p025/2599p212/BGS_BRIGHT_tgid_39628291233025021
# Error in 190: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-320p020-330p025/3269p222/BGS_BRIGHT_tgid_39628314742099506
# Error in 192: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-320p020-330p025/3262p230/BGS_BRIGHT_tgid_39628331468987167
# Error in 193: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-110p020-120p025/1194p235/BGS_BRIGHT_tgid_39628339392023938
# Error in 195: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-260p020-270p025/2646p242/BGS_BRIGHT_tgid_39628358220258582
# Error in 196: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-190p020-200p025/1974p247/BGS_BRIGHT_tgid_39628368198503970
# Error in 197: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-250p020-260p025/2557p247/BGS_BRIGHT_tgid_39628369087695223
# Error in 200: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-330p025-340p030/3308p255/BGS_BRIGHT_tgid_39628386653443555
# Error in 201: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-340p025-350p030/3443p257/BGS_BRIGHT_tgid_39628392311555252
# Error in 203: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-350p025-360p030/3556p277/BGS_BRIGHT_tgid_39628435659688905
# Error in 204: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-330p025-340p030/3332p280/BGS_BRIGHT_tgid_39628440671881757
# Error in 205: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-160p025-170p030/1667p285/BGS_BRIGHT_tgid_39628448859163011
# Error in 211: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-230p030-240p035/2391p300/BGS_BRIGHT_tgid_39628481587318393
# Error in 213: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-220p030-230p035/2203p305/BGS_BRIGHT_tgid_39628491766894961
# Error in 214: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-220p030-230p035/2280p307/BGS_BRIGHT_tgid_39628497085271258
# Error in 216: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-000p030-010p035/0098p315/BGS_BRIGHT_tgid_39628509492021847
# Error in 220: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-220p030-230p035/2214p322/BGS_BRIGHT_tgid_39628527942766564
# Error in 221: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-330p030-340p035/3370p325/BGS_BRIGHT_tgid_39628534695595474
# Error in 222: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-350m010-360m005/3563m052/BGS_BRIGHT_tgid_39636460055298096
# Error in 224: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-140p000-150p005/1403p007/BGS_FAINT_tgid_39627805201271100
# Error in 226: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-030p025-040p030/0388p280/BGS_FAINT_tgid_39628436301416079
# Error in 231: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-070m010-080m005/0711m087/ELG_tgid_39627575210803442
# Error in 232: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-070m010-080m005/0752m087/ELG_tgid_39627575277912517
# Error in 233: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-180m010-190m005/1826m070/ELG_tgid_39627618982563721
# Error in 235: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-130m010-140m005/1356m057/ELG_tgid_39627648237833075
# Error in 237: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-140m005-150p000/1456m030/ELG_tgid_39627714692383790
# Error in 238: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-180m005-190p000/1863m025/ELG_tgid_39627727455655340
# Error in 242: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-230m005-240p000/2338m005/ELG_tgid_39627776570953187
# Error in 245: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-140p000-150p005/1446p007/ELG_tgid_39627805272576481
# Error in 246: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-140p000-150p005/1486p022/ELG_tgid_39627841578470731
# Error in 247: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-170p000-180p005/1783p025/ELG_tgid_39627848117390910
# Error in 249: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-130p000-140p005/1348p035/ELG_tgid_39627871534186580
# Error in 251: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-030p005-040p010/0337p087/ELG_tgid_39627996050492179
# Error in 252: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-150p005-160p010/1515p095/ELG_tgid_39628015910520972
# Error in 253: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-230p010-240p015/2325p107/ELG_tgid_39628047007092823
# Error in 254: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-230p020-240p025/2358p245/ELG_tgid_39628363286974951
# Error in 256: /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-200p030-210p035/2040p322/ELG_tgid_39628527695301215

# %%
data_scarlet_f[data_scarlet_f["TARGETID"]==39627860310231813]["FILE_PATH","PCNN_FRAGMENT"]
# Out:
# <Table length=1>
#                                                         FILE_PATH                                                         ...
#                                                          bytes128                                                         ...
# ------------------------------------------------------------------------------------------------------------------------- ...
# /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-180p000-190p005/1851p030/ELG_tgid_39627860310231813 ...

# %%
##given all these pdfs, make a scroolabe one

from desi_lowz_funcs import get_scrollable_pdfs
import glob

# %%
get_scrollable_pdfs(all_scar_imgs, "/pscratch/sd/v/virajvm/trash/scarlet_all_comp.pdf")
# Out:
# Scrollable pdf saved at /pscratch/sd/v/virajvm/trash/scarlet_all_comp.pdf

# %% [markdown]
# ## Scarlet photometry vs. our photometry comparison
#
# We remove the scarlet models that do not look correct after VI'ing

# %%
##loop through the files

all_best_mags = []
all_trac_based_mags = []
all_scar_mags = []
all_scar_R4_mags = []

bad_models = [39627673282024515, 39627678508126278, 39627697344746107, 39627703434871529, 39627708442870674,
39627737085772411, 39627764231307714,  39627764231307714, 39627775753060564, 39627776650644919, 
39627777950881432, 39627817771599530, 39627835534480059, 39627848771699217, 39627857147727552, 
39627872935084634, 39627890874123509, 39627923212209600, 39627932791999997, 39627981563363983, 
39627981768885600, 39628033274939609, 39628124182286640, 39628131211939268, 39628180209797010, 
39628197762959956, 39628249424200280, 39628322673530195, 39628352629245052, 39628459705635056,
39628414809801156, 39627329424596254, 39627335137233103] 

print(len(data_scarlet_f))

for i in range(len(data_scarlet_f)):

    tgidi = data_scarlet_f["TARGETID"].data[i]
    if i in bad_models:
        pass
    else:        
        try:
            file_path = data_scarlet_f["FILE_PATH"][i]
    
            scar_R4_mags = np.load(file_path + "/scarlet_mags_R4.npy")
        
            all_scar_R4_mags.append(scar_R4_mags[0])
            all_scar_R4_mags.append(scar_R4_mags[1])
            all_scar_R4_mags.append(scar_R4_mags[2])
    
            #get the scarlet mags
            scar_mags = np.load(file_path + "/scarlet_mags.npy")
        
            all_scar_mags.append(scar_mags[0])
            all_scar_mags.append(scar_mags[1])
            all_scar_mags.append(scar_mags[2])
    
            
            #load in the aperture cog mags
            gmag_best = data_scarlet_f["MAG_G_BEST"][i]
            rmag_best = data_scarlet_f["MAG_R_BEST"][i]
            zmag_best = data_scarlet_f["MAG_Z_BEST"][i]

            gmag_tracb = data_scarlet_f["TRACTOR_ONLY_MAG_G_FINAL"][i]
            rmag_tracb = data_scarlet_f["TRACTOR_ONLY_MAG_R_FINAL"][i]
            zmag_tracb = data_scarlet_f["TRACTOR_ONLY_MAG_Z_FINAL"][i]
        
            ##get the tractor based mgs
        
            all_best_mags.append(gmag_best)
            all_best_mags.append(rmag_best)
            all_best_mags.append(zmag_best)

            all_trac_based_mags.append(gmag_tracb)
            all_trac_based_mags.append(rmag_tracb)
            all_trac_based_mags.append(zmag_tracb)
            

    
        except:
            print(f"{i} index did not work")

all_best_mags = np.array(all_best_mags)
all_trac_based_mags = np.array(all_trac_based_mags)

all_scar_mags = np.array(all_scar_mags)
all_scar_R4_mags = np.array(all_scar_R4_mags)

# mag_diffs = all_best_mags - all_scar_mags

mag_trac_diffs_r4 = all_trac_based_mags - all_scar_R4_mags
mag_diffs_r4 = all_best_mags - all_scar_R4_mags
# Out:
# 250
# 0 index did not work
# 3 index did not work
# 8 index did not work
# 10 index did not work
# 12 index did not work
# 19 index did not work
# 20 index did not work
# 31 index did not work
# 33 index did not work
# 34 index did not work
# 35 index did not work
# 37 index did not work
# 41 index did not work
# 42 index did not work
# 46 index did not work
# 48 index did not work
# 49 index did not work
# 50 index did not work
# 52 index did not work
# 55 index did not work
# 57 index did not work
# 59 index did not work
# 64 index did not work
# 66 index did not work
# 67 index did not work
# 68 index did not work
# 70 index did not work
# 73 index did not work
# 74 index did not work
# 76 index did not work
# 79 index did not work
# 82 index did not work
# 83 index did not work
# 90 index did not work
# 95 index did not work
# 102 index did not work
# 103 index did not work
# 104 index did not work
# 112 index did not work
# 113 index did not work
# 119 index did not work
# 129 index did not work
# 131 index did not work
# 132 index did not work
# 136 index did not work
# 141 index did not work
# 146 index did not work
# 147 index did not work
# 148 index did not work
# 151 index did not work
# 154 index did not work
# 155 index did not work
# 158 index did not work
# 159 index did not work
# 160 index did not work
# 161 index did not work
# 163 index did not work
# 167 index did not work
# 168 index did not work
# 169 index did not work
# 171 index did not work
# 173 index did not work
# 176 index did not work
# 178 index did not work
# 179 index did not work
# 181 index did not work
# 182 index did not work
# 183 index did not work
# 184 index did not work
# 186 index did not work
# 187 index did not work
# 189 index did not work
# 190 index did not work
# 191 index did not work
# 194 index did not work
# 195 index did not work
# 197 index did not work
# 198 index did not work
# 199 index did not work
# 205 index did not work
# 207 index did not work
# 208 index did not work
# 210 index did not work
# 214 index did not work
# 215 index did not work
# 216 index did not work
# 218 index did not work
# 220 index did not work
# 224 index did not work
# 225 index did not work
# 226 index did not work
# 228 index did not work
# 230 index did not work
# 231 index did not work
# 235 index did not work
# 238 index did not work
# 239 index did not work
# 241 index did not work
# 243 index did not work
# 244 index did not work
# 245 index did not work
# 247 index did not work
# 249 index did not work

# %%
from desi_lowz_funcs import make_alternating_plot
from scipy import stats

# %%
len(mag_trac_diffs_r4), len(mag_diffs_r4)
# Out:
# (441, 441)

# %%
np.median(mag_trac_diffs_r4), stats.median_abs_deviation(mag_trac_diffs_r4, scale = 'normal')
# Out:
# (0.029587979506011663, 0.22711241684527866)

# %%
np.median(mag_diffs_r4), stats.median_abs_deviation(mag_diffs_r4, scale = 'normal')
# Out:
# (0.03969231123926775, 0.13434973030926808)

# %%
ax = make_subplots(ncol = 1, nrow = 1)

ax[0].hist(mag_diffs_r4,range=(-1,1),bins=np.arange(-1.1,1.1,0.1),color = "darkgrey",label=r"X=COG")

ax[0].hist(mag_trac_diffs_r4,range=(-1,1),bins=np.arange(-1.1,1.1,0.1),color = "#5D3A9B",
           histtype="step",lw=2, label = r"X=TRACTOR_BASED",alpha=0.85)

# ax[0].hist(mag_diffs,range=(-1,1),bins=15,color = "k",histtype = "step",ls = "-.",lw = 1,alpha=0.75)

ax[0].set_xlim([-1,1])

fs=14
# ax[0].text(0.23,0.85,rf"bias = {np.median(mag_diffs_r4):.2f}",fontsize = fs,ha="center",va="center",
#           transform=ax[0].transAxes )

# ax[0].text(0.23,0.77,rf"$\sigma_{{\rm NMAD}}$ = {stats.median_abs_deviation(mag_diffs_r4, scale = 'normal'):.2f}",fontsize = fs,ha="center",va="center",
#           transform=ax[0].transAxes )

xgrid = np.linspace(0,160,100)
make_alternating_plot(ax[0],0*xgrid,xgrid,dash_len=1,color_1="yellowgreen",color_2="k",lw=1)

ax[0].legend(frameon=False,fontsize = 12,loc="upper left")

ax[0].set_ylim([0,160])
ax[0].set_xlabel(r"mag$_{\rm X}$ - mag$_{\rm Scarlet}$",fontsize = 15)
ax[0].set_ylabel(r"Number",fontsize = 15)

plt.savefig("/global/homes/v/virajvm/galaxy_image_prior/paper_1/plots/scarlet_aper_compare.pdf",bbox_inches="tight")
plt.show()

# %%
targetids_to_plot = [
    39627696736569216,
    39627902668510595,
    39627950118668787,
    39627893835307165,
    39627957563555904,
    39627744694244896,
    39627872356275243,
    39627740013401179,
    39627951129493854,
    39627757478481897,
    39627829515651318,
    39627777950881432,
    39627755704288400,
    39627752084603161,
    39627666902485913,
    39628504479829681,
    39627667204478543,
    39628527288452786,
    39627971878718838,
    39627854903771809,
    39627835962296788,
    39627896603545910,
    39627691422387329,
    39627643653460508,
    39627866891094974,
    39627790391187481,
    39627600171107076,
    39628147238374191,
    39627685319676194,
    39627703506176030,
    39628470438857978,
    39628481516012917,
    39627751577095177,
    39627973615161184,
    39627722128887172,
    39627669465203619,
    39627906002981591,
    39627847312083386,
]

# %%
final_tgids_to_plot= [39627950118668787, 39627906002981591, 39627685319676194, 39627691422387329, 39628527288452786, 39628504479829681, 39627740013401179]

# %%
def plot_f(tgid, data_scarlet, plot_label = False):
    '''
    Input is the TARGETID we want to plot, and data_scarlet is the entire catalog
    '''

    index = np.where(data_scarlet["TARGETID"] == tgid)[0][0]
    
    ra = data_scarlet["RA"][index]
    dec = data_scarlet["DEC"][index]
    zred = data_scarlet["Z"][index]
    
    file_path = data_scarlet["FILE_PATH"][index]
    img_path = data_scarlet["IMAGE_PATH"][index]


    img_data_total = fits.open(img_path)[0].data

    wcs = WCS(fits.getheader(img_path))
    
    print(file_path)
    
    scar_mags = np.load( file_path + "/scarlet_mags_R4.npy")

    #get the dwarf only model with scarlet
    scarlet_total_model = np.load(file_path + "/total_model_rgb.npy")
    scarlet_model_rgb = np.load(file_path + "/dwarf_model_rgb.npy")
    scarlet_resid_rgb = np.load(file_path + "/model_residual_rgb.npy")
    bounding_box_coords = np.load(file_path + "/bounding_box_coords.npy")

    shift_y, _, shift_x, _ = bounding_box_coords
    
    ##### PREPARING THE ACTUAL IMAGES!
    img_data = img_data_total[:, bounding_box_coords[0] : bounding_box_coords[1], bounding_box_coords[2] : bounding_box_coords[3] ]
    img_rgb = sdss_rgb([img_data[0],img_data[1],img_data[2]], ["g","r","z"], scales=dict(g=(2,6.0), r=(1,3.4), z=(0,2.2)), m=0.03)

    ## load the dwarf only model with tractor!!
    
    tractor_bkg_model = np.load(file_path + "/tractor_background_model.npy")
    
    tractor_source_model = np.load(file_path + "/tractor_source_model.npy")
    tractor_source_model = tractor_source_model[ :, bounding_box_coords[0] : bounding_box_coords[1], bounding_box_coords[2] : bounding_box_coords[3] ]
    
    tractor_blend_model = np.load(file_path + "/tractor_blend_remove_model.npy")
    
    tractor_dwarf_model = img_data_total - tractor_bkg_model - tractor_blend_model
    tractor_dwarf_model = tractor_dwarf_model[ :, bounding_box_coords[0] : bounding_box_coords[1], bounding_box_coords[2] : bounding_box_coords[3] ]
    #apply the aperture mask
    aper_cog_mask = np.load(file_path + "/final_mask_cog.npy")
    aper_cog_mask = aper_cog_mask[bounding_box_coords[0] : bounding_box_coords[1], bounding_box_coords[2] : bounding_box_coords[3] ]
    
    tractor_dwarf_model[:, aper_cog_mask] = 0
    tractor_dwarf_model_rgb = sdss_rgb([tractor_dwarf_model[0],tractor_dwarf_model[1],tractor_dwarf_model[2]], ["g","r","z"], scales=dict(g=(2,6.0), r=(1,3.4), z=(0,2.2)), m=0.03)

    desi_fiber_pos = np.load(file_path + "/fiber_pix_pos_org.npy")
    #we need to update this 

    desi_fiber_pos = desi_fiber_pos - np.array([bounding_box_coords[0] , bounding_box_coords[2]] )
    
    fig,ax = make_subplots(ncol = 1, nrow = 4, return_fig = True,row_spacing = 0.)

    ax[3].imshow(img_rgb,origin="lower",zorder = 0)

    circle = patches.Circle( (desi_fiber_pos[1], desi_fiber_pos[0]),3, color='r', fill=False, linewidth=1.5,ls ="-")
    ax[3].add_patch(circle)
    
    fs = 14
    if plot_label:
        # ax[0].set_ylabel(r"Scarlet Residuals",fontsize = fs)
        ax[0].set_ylabel(r"Scarlet Model",fontsize = fs)
        ax[1].set_ylabel(r"Our Reconstruction",fontsize = fs)
        ax[2].set_ylabel(r"DESI Source Tractor Model",fontsize = fs)
        ax[3].set_ylabel(r"$grz$ image",fontsize = fs)
            
    ax[3].text(0.5, 0.95,f"({ra:.3f}, {dec:.3f}), z = {zred:.3f}",color = "white",fontsize = 12,
                 transform=ax[3].transAxes, ha = "center", verticalalignment='top')
    
    fst = 13

    ax[2].text(
    0.5, 0.925,
    rf"$\mathrm{{mag_{{DR9}}}}$: ({data_scarlet['MAG_G'][index]:.1f}, "
    rf"{data_scarlet['MAG_R'][index]:.1f}, "
    rf"{data_scarlet['MAG_Z'][index]:.1f})",
    ha="center", va="center",
    fontsize=fst, color="white",
    transform=ax[2].transAxes)

    
    ax[1].text(
    0.5, 0.925,
    rf"$\mathrm{{mag_{{Best}}}}$: ({data_scarlet['MAG_G_BEST'][index]:.1f}, "
    rf"{data_scarlet['MAG_R_BEST'][index]:.1f}, "
    rf"{data_scarlet['MAG_Z_BEST'][index]:.1f})",
    ha="center", va="center",
    fontsize=fst, color="white",
    transform=ax[1].transAxes)

    ax[0].text(
    0.5, 0.925,
    rf"$\mathrm{{mag_{{Scarlet}}}}$: ({scar_mags[0]:.1f}, "
    rf"{scar_mags[1]:.1f}, "
    rf"{scar_mags[2]:.1f})",
    ha="center", va="center",
    fontsize=fst, color="white",
    transform=ax[0].transAxes
)

    tractor_source_rgb = sdss_rgb(tractor_source_model)
    ax[2].imshow(tractor_source_rgb, origin="lower")
    ax[1].imshow(tractor_dwarf_model_rgb,origin="lower")    
    ax[0].imshow(scarlet_model_rgb,origin="lower")
    # ax[0].imshow(scarlet_resid_rgb,origin="lower")

    ## show the ellipse !!
    ra_cen, dec_cen = data_scarlet["RA"][index], data_scarlet["DEC"][index]
    r50_pix = data_scarlet["R50_R"][index]/0.262
    shape_params = data_scarlet["SHAPE_PARAMS"][index]
    aper_xcen, aper_ycen,_ = wcs.all_world2pix(ra_cen,dec_cen,0,1)

    aper_xcen -= shift_x
    aper_ycen -= shift_y

    #we need to shift the center!!

    ell = Ellipse((aper_xcen, aper_ycen), 2 * scale_f * r50_pix, 2 * scale_f * r50_pix * shape_params[0], angle = shape_params[1] - 90,
                  facecolor='none', edgecolor="white", lw=1, ls="-", alpha=0.75)
    ax[1].add_patch(ell)


    org_size = np.shape(img_data)[1]

    for axi in ax:
        axi.set_xticks([])
        axi.set_yticks([])

        bar_frac = 15/(org_size * 0.262)

        x_start_frac = 0.07  # 7% from left
        y_start_frac = 0.07  # 7% from bottom
        
        # Draw the scale bar in axes coordinates
        axi.plot([x_start_frac, x_start_frac + bar_frac],
                [y_start_frac, y_start_frac],
                color='white', lw=1, transform=axi.transAxes)    
    

    plt.savefig(f"/global/homes/v/virajvm/galaxy_image_prior/paper_1/plots/scarlet_model_{index}.png",bbox_inches="tight")
    plt.close()

# %%
for tgidi in final_tgids_to_plot:
    try:
        plot_f(tgidi, data_scarlet_f,plot_label=True)
    except:
        pass
# Out:
# /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-150p005-160p010/1539p067/BGS_BRIGHT_tgid_39627950118668787
# /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-030p005-040p010/0332p050/BGS_BRIGHT_tgid_39627906002981591
# /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-190m005-200p000/1926m042/BGS_BRIGHT_tgid_39627685319676194
# /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-170p030-180p035/1754p322/BGS_BRIGHT_tgid_39628527288452786
# /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-020p030-030p035/0211p312/BGS_BRIGHT_tgid_39628504479829681
# /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-210m005-220p000/2148m020/BGS_BRIGHT_tgid_39627740013401179

# %% [markdown]
# ## VERY DIFFUSE OBJECT EXAMPLE PLOT

# %%
data_bgsb = Table.read("/pscratch/sd/v/virajvm/catalog_dr1_dwarfs/iron_photometry/iron_BGS_BRIGHT_shreds_catalog_w_aper_mags.fits")

# %%
# let us consolidate this 
from consolidate_photometry import consolidate_new_photo, consolidate_positions_and_shapes


data_bgsb = consolidate_new_photo(data_bgsb,sample="BGS_BRIGHT")

data_bgsb = consolidate_positions_and_shapes(data_bgsb)
# Out:
# Added PCNN values!
# FRACTION REVERT BACK TO TRACTOR: 0.23541726139499478
# Need to include the VI column that only does the aperture no subtract photo
# Adding the photo maskbits
# MASKBIT=2^0, cog nan mask, 0.0030
# MASKBIT=2^1, cog not converge, fraction: 0.059616
# MASKBIT=2^2, bad resid, fraction : 0.0056
# MASKBIT=2^3, cog curve decrease, fraction: 0.0095
# MASKBIT=2^4, aperfrac-in image, fraction: 0.000999
# MASKBIT=2^5, aperfrac-mask image, fraction: 0.047055
# MASKBIT=2^6, image-frac mask, fraction: 0.000809
# MASKBIT=2^7, bad colors, fraction: 0.000333
# MASKBIT=2^8, source not on segment, fraction: 0.0000
# MASKBIT=2^9, within star mask radius and not just a simple blend, fraction: 0.102151
# MASKBIT=2^10, aper-cen masked, fraction: 0.048958
# MASKBIT=2^11, no seg found, fraction: 0.000048
# MASKBIT=2^12, near sga outskirts, fraction: 0.013798
# Fraction of sources where org trac is likely good = 0.5378247216671425
# Updating the maskbits to reflect some objects reverted to original Tractor photometry
# MASKBIT=2^0, cog nan mask, 0.0030
# MASKBIT=2^7, bad colors, fraction: 0.000333
# MASKBIT=2^11, no seg found, fraction: 0.000048
# MASKBIT=2^12, near sga outskirts, fraction: 0.013798
# MASKBIT=2^13, bad rchisq, fraction: 0.131221
# MASKBIT=2^14, low snr, fraction: 0.001903
# MASKBIT=2^15, Tractor maskbit flagged: 0.0403
#
# --- Maskbit Statistics (n = 21018) ---
# Fraction with no maskbit on = 0.8701113331430202
# Bit  0 (2^0  =    1)  ->  0.30% fraction
# Bit  1 (2^1  =    2)  ->  1.15% fraction
# Bit  2 (2^2  =    4)  ->  0.22% fraction
# Bit  3 (2^3  =    8)  ->  0.53% fraction
# Bit  4 (2^4  =   16)  ->  0.08% fraction
# Bit  5 (2^5  =   32)  ->  0.43% fraction
# Bit  6 (2^6  =   64)  ->  0.03% fraction
# Bit  7 (2^7  =  128)  ->  0.03% fraction
# Bit  8 (2^8  =  256)  ->  0.00% fraction
# Bit  9 (2^9  =  512)  ->  2.44% fraction
# Bit 10 (2^10 = 1024)  ->  0.75% fraction
# Bit 11 (2^11 = 2048)  ->  0.00% fraction
# Bit 12 (2^12 = 4096)  ->  1.38% fraction
# Bit 13 (2^13 = 8192)  ->  5.52% fraction
# Adding the consolidated RA,DEC, and SHAPE columns
# 100%|██████████| 21018/21018 [00:00<00:00, 288390.82it/s]
# 100%|██████████| 21018/21018 [00:00<00:00, 289123.84it/s]
# Consolidated RA, DEC, and SHAPE_PARAMS columns added. Added PHOTOMETRY_UPDATED column

# %%
nsa_cat = Table.read("/pscratch/sd/v/virajvm/catalog/nsa_v1_0_1.fits")
# 39627824100806546

# %%
data_egs = data_bgsb[data_bgsb["TARGETID"] == 39627824100806546]

# %%
data_egs["FILE_PATH"]
# Out:
# <Column name='FILE_PATH' dtype='bytes128' length=1>
# /pscratch/sd/v/virajvm/redo_photometry_plots/all_deshreds/south/sweep-180p000-190p005/1868p015/BGS_BRIGHT_tgid_39627824100806546

# %%
from desi_lowz_funcs import find_objects_nearby

nsa_egs = find_objects_nearby(nsa_cat, find_ra = 186.94195083006372, find_dec = 1.6002666871011568, ra="RA",dec="DEC")


# nsa_cat

# %%
nsa_egs["ELPETRO_BA","ELPETRO_PHI","ELPETRO_TH50_R","RA","DEC"]
# Out:
# <Table length=1>
# ELPETRO_BA ELPETRO_PHI ELPETRO_TH50_R         RA                DEC
#  float32     float32      float32          float64            float64
# ---------- ----------- -------------- ------------------ ------------------
# 0.87256676   145.20984      29.847254 186.94176121638188 1.6002227774547761

# %%
#obtaining the NSA magnitudes to compare with
nsa_petro_gflux = nsa_egs["ELPETRO_FLUX"][:,3].data
nsa_petro_rflux = nsa_egs["ELPETRO_FLUX"][:,4].data
nsa_petro_zflux = nsa_egs["ELPETRO_FLUX"][:,6].data

nsa_petro_gmag = 22.5 - 2.5*np.log10(nsa_petro_gflux.data)[0]
nsa_petro_rmag = 22.5 - 2.5*np.log10(nsa_petro_rflux.data)[0]
nsa_petro_zmag = 22.5 - 2.5*np.log10(nsa_petro_zflux.data)[0]

# %%
nsa_petro_gmag,nsa_petro_rmag,nsa_petro_zmag
# Out:
# (15.850157141685486, 15.68455457687378, 14.852027893066406)

# %%
from desi_lowz_funcs import process_img
from astropy.wcs import WCS
from matplotlib.patches import Ellipse, Circle

# %%
def cut_array(org_data, new_cutout_size = 300,invert=False):

    aper_xcen = np.shape(org_data)[1]/2
    aper_ycen = np.shape(org_data)[1]/2
    
    x_min_new = int(aper_xcen - int(new_cutout_size))
    x_max_new = int(aper_xcen + int(new_cutout_size))
    y_min_new = int(aper_ycen - int(new_cutout_size))
    y_max_new = int(aper_ycen + int(new_cutout_size))

    if invert:
        return org_data[y_min_new : y_max_new, x_min_new : x_max_new, : ]

    else:
        return org_data[:, y_min_new : y_max_new, x_min_new : x_max_new ]
    

## make a multi-panel plot of how the org grz image, include NSA photometr there, include DESI source model, 
## include our original aperture reconstruction, and then the full scarlet model of, scarlet bkg and then residuals 

file_path = data_egs["FILE_PATH"][0]

data_arr = fits.open(data_egs["IMAGE_PATH"][0])[0].data

print(data_arr.shape)

wcs = WCS(fits.getheader(data_egs["IMAGE_PATH"][0]))

new_cutout_size = 600
img_rgb, shift = process_img(data_arr, cutout_size=new_cutout_size, org_size = data_arr.shape[1], return_shift=True)

#get the desi source model
desi_source = np.load(file_path + "/tractor_source_model.npy")
desi_source_rgb = process_img(desi_source,cutout_size=new_cutout_size, org_size = desi_source.shape[1])
# desi_source_cut = cut_array(desi_source, new_cutout_size)
# desi_source_rgb = sdss_rgb(desi_source_cut)

##get our original reconstruction of the dwarf!!
# org_recon = np.load(file_path + "/final_reconstruct_galaxy.npy")
org_recon = np.load(file_path + "/final_reconstruct_galaxy_no_cog_mask.npy")

org_recon_rgb = process_img(org_recon,cutout_size=new_cutout_size, org_size = org_recon.shape[1])
# org_recon_cut = cut_array(org_recon, new_cutout_size)
# org_recon_rgb = sdss_rgb(org_recon_cut)

##get our original reconstruction of the dwarf!!
scar_dwarf_rgb = np.load(file_path + "/dwarf_model_rgb.npy")
# scar_dwarf_rgb = process_img( scar_dwarf,cutout_size=new_cutout_size,org_size=scar_dwarf.shape[1] )
# print(scar_dwarf.shape, scar_dwarf_rgb.shape)
# scar_dwarf_rgb = cut_array(scar_dwarf, new_cutout_size,invert=True)

scar_bkg_rgb = np.load(file_path + "/nondwarf_model_rgb.npy")
# scar_bkg_rgb = cut_array(scar_bkg, new_cutout_size,invert=True)

scar_resid_rgb = np.load(file_path + "/model_residual_rgb.npy")
# scar_resid_rgb = cut_array(scar_resid, new_cutout_size,invert=True)

ax = make_subplots(ncol = 2, nrow = 3,col_spacing = 0.05, row_spacing = 0.4)

for axi in ax:
    axi.set_xticks([])
    axi.set_yticks([])

##plot the twice the half light aperture of this object
## show the ellipse !!
ra_cen, dec_cen = data_egs["RA"][0], data_egs["DEC"][0]
r50_pix = data_egs["R50_R"][0]/0.262
shape_params = data_egs["SHAPE_PARAMS"][0]
aper_xcen, aper_ycen,_ = wcs.all_world2pix(ra_cen,dec_cen,0,1)

aper_xcen -= shift
aper_ycen -= shift

#we need to shift the center!!
scale_f = 2
ell = Ellipse((aper_xcen, aper_ycen), 2 * scale_f * r50_pix, 2 * scale_f * r50_pix * shape_params[0], angle = shape_params[1] - 90,
              facecolor='none', edgecolor="white", lw=1.5, ls="-", alpha=0.75)
ax[5].add_patch(ell)


##adding the NSA aperture here!!
# https://data.sdss.org/datamodel/files/ATLAS_DATA/ATLAS_MAJOR_VERSION/nsa.html -> datamodel for NSA!
ra_nsa, dec_nsa = nsa_egs["RA"][0], nsa_egs["DEC"][0]
r50_nsa_pix =  nsa_egs["ELPETRO_TH50_R"][0]/0.262
ba_nsa = nsa_egs["ELPETRO_BA"][0]
phi_nsa = nsa_egs["ELPETRO_PHI"][0] #in degrees

aper_x_nsa, aper_y_nsa,_ = wcs.all_world2pix(ra_nsa,dec_nsa,0,1)

aper_x_nsa -= shift
aper_y_nsa -= shift

scale_f = 2
ell = Ellipse((aper_x_nsa, aper_y_nsa), 2 * scale_f * r50_nsa_pix, 2 * scale_f * r50_nsa_pix * ba_nsa, angle = phi_nsa - 90,
              facecolor='none', edgecolor="orchid", lw=1.5, ls="--", alpha=0.7)
ax[4].add_patch(ell)

##


ax[4].imshow(img_rgb,origin="lower",rasterized=True)
ax[3].imshow(desi_source_rgb, origin="lower",rasterized=True)
ax[5].imshow(org_recon_rgb,origin="lower",rasterized=True)
ax[2].imshow(scar_dwarf_rgb,origin="lower",rasterized=True)
ax[0].imshow(scar_bkg_rgb,origin="lower",rasterized=True)
ax[1].imshow(scar_resid_rgb,origin="lower",rasterized=True)

fs = 17
ax[4].set_title("$grz$ image",fontsize = fs)
ax[3].set_title("DESI Source Model",fontsize = fs)
ax[5].set_title("Our Reconstruction",fontsize = fs)
ax[2].set_title("Scarlet Dwarf Model",fontsize = fs)
ax[0].set_title("Scarlet Bkg Model",fontsize = fs)
ax[1].set_title("Scarlet Residuals",fontsize = fs)

##include the photometry in relevant panels now 

fs= 15
ax[4].text(0.5,0.925, rf"mag$_{{\rm NSA}}$: ({nsa_petro_gmag:.1f},{nsa_petro_rmag:.1f},{nsa_petro_zmag:.1f})",
          ha="center",va="center", transform=ax[4].transAxes,color = "orchid",fontsize = fs,alpha=0.96)

ax[3].text(0.5,0.925, rf"mag$_{{\rm DR9}}$: ({data_egs['MAG_G'][0]:.1f},{data_egs['MAG_R'][0]:.1f},{data_egs['MAG_Z'][0]:.1f})",
          ha="center",va="center", transform=ax[3].transAxes,color = "white",fontsize = fs)


cog_mags = np.load(file_path + "/new_cog_mags.npy")
aper_gmag, aper_rmag, aper_zmag = cog_mags[0], cog_mags[1], cog_mags[2]

ax[5].text(0.5,0.925, rf"mag$_{{\rm Best}}$: ({aper_gmag:.1f},{aper_rmag:.1f},{aper_zmag:.1f})",
          ha="center",va="center", transform=ax[5].transAxes,color = "white",fontsize = fs)

scar_mags = np.load(file_path + "/scarlet_mags.npy")
scar_gmag, scar_rmag, scar_zmag = scar_mags[0], scar_mags[1], scar_mags[2]


ax[2].text(0.5,0.925, rf"mag$_{{\rm Scarlet}}$: ({scar_gmag:.1f},{scar_rmag:.1f},{scar_zmag:.1f})",
          ha="center",va="center", transform=ax[2].transAxes,color = "white",fontsize = fs)

##include a bar indicating 60''
bar_frac = 60/(600 * 0.262)

x_start_frac = 0.07  # 7% from left
y_start_frac = 0.07  # 7% from bottom

ax[4].plot([x_start_frac, x_start_frac + bar_frac],
            [y_start_frac, y_start_frac],color='white', lw=1, transform=ax[4].transAxes)    
fs=14
ax[4].text( x_start_frac + 0.45*bar_frac, y_start_frac*1.1, r"$1'$",fontsize = fs,color = "white",
           transform=ax[4].transAxes )
    
plt.savefig("/global/homes/v/virajvm/galaxy_image_prior/paper_1/plots/very_diffuse_example.pdf",bbox_inches="tight")

plt.show()
# Out:
# (3, 1316, 1316)
